# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils import data
from torchvision.datasets import ImageFolder
from torchvision import transforms, datasets
from torchvision.utils import make_grid, save_image

# %%
# the number of images to process in one go
batch_size = 64
# the path where our images are
image_path = os.path.join('/scratch','yns207','imgs','mgan')
# check that we have access to a GPU, pytorch version, and the number of gpus
print('do we have gpu access? {} \n what is torch version? {} \n how many gpus? {}'.format(torch.cuda.is_available(), torch.__version__, torch.cuda.device_count()))
# Out:
# do we have gpu access? True
#  what is torch version? 0.2.0_4
#  how many gpus? 1

# %%
# this loads the monster data
# scales it to be 64x64, converts
# it to a torch tensor and then
# normalizes the input to be between
# -1 and 1, also shuffle the dataset
monster_transform = transforms.Compose([
         transforms.Scale(64),
         transforms.CenterCrop(64),
         transforms.ToTensor(), 
         transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)),
        ])
# this loads the actual files and applies the above transformation
monster_dataset = ImageFolder(image_path, monster_transform)
# thes describes how to load that data, whether to shuffle,
# how mnay cpus (workers to use), ett. it gets batches of 
# data so for example grabbing 64 images at once
monster_loader = data.DataLoader(dataset=monster_dataset, 
                              batch_size=batch_size,
                              shuffle=True,
                              num_workers=1)

# %%
# check the shape of our pach of images,
# this seems right, we have 64 images and
# they are sized 64x64x3 
for img in monster_loader:
    # renomalize a single image
    single_image = img[0][0]
    single_image= (single_image*0.5)+0.5
    single_image = single_image.clamp(0,1)
    single_image = single_image.numpy()
    # move the dimensions around to get them right
    single_image = np.transpose(single_image, (1, 2, 0))
    # plot image
    print('image size: ',single_image.shape)
    plt.imshow(single_image)
    plt.axis('off')
    plt.show()
    break
# Out:
# image size:  (64, 64, 3)

# %%
# how many images do we have?
sum([x[0].shape[0] for x in monster_loader])
# Out:
# 14774

# %%
# parameters for various parts of the model
n_epochs = 125
lr = 0.0002
label_smooth = 0.9
pokemon_models = os.path.join('/scratch', 'yns207', 'pokemon_models')
noise_dim = 100
d_filter_depth_in = 3

# %%
# create our generator network
# this network will take in 
# random noise and output a
# monster.
class Generator(nn.Module):
    # define the model it has 5 transpose
    # convolutions and uses relu activations
    # it has a TanH activation on the last
    # layer
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(noise_dim, 
                              512, 
                              kernel_size=4, 
                              stride=1, 
                              padding=0,
                              bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(),

            nn.ConvTranspose2d(512, 
                              256, 
                              kernel_size=4, 
                              stride=2,
                              padding=1,
                              bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            
            nn.ConvTranspose2d(256, 
                              128, 
                              kernel_size=4, 
                              stride=2, 
                              padding=1,
                              bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            
            nn.ConvTranspose2d(128, 
                              64, 
                              kernel_size=4, 
                              stride=2, 
                              padding=1,
                              bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            
            nn.ConvTranspose2d(64, 
                               d_filter_depth_in,
                               kernel_size=4,
                               stride=2,
                               padding=1,
                               bias=False),
            nn.Tanh()
        )
        
    # define how to propagate 
    # through this network
    def forward(self, inputs):
        output = self.main(inputs)
        return output

# create the model that will evaluate 
# the generated monsters
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(in_channels=d_filter_depth_in, 
                      out_channels=64, 
                      kernel_size=4, 
                      stride=2,
                      padding=1,
                      bias=False),
            nn.LeakyReLU(0.2),

            nn.Conv2d(in_channels=64, 
                      out_channels=128, 
                      kernel_size=3, 
                      stride=2,
                      padding=1,
                      bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            
            nn.Conv2d(in_channels=128, 
                      out_channels=256, 
                      kernel_size=4, 
                      stride=2,
                      padding=1,
                      bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),

            
            nn.Conv2d(in_channels=256, 
                      out_channels=512, 
                      kernel_size=4, 
                      stride=2,
                      padding=1,
                      bias=False),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),
            
            nn.Conv2d(in_channels=512, 
                      out_channels=1, 
                      kernel_size=4, 
                      stride=1,
                      padding=0,
                      bias=False),
            nn.Sigmoid()
        )
        
    # define forward porpagation
    # through that model
    def forward(self, inputs):
        output = self.main(inputs)
        return output.view(-1, 1).squeeze(1)

# %%
# utility functions

# this iniitilaizes the parameters
# to good rnadom values, you can
# do more research on your own
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv2d') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:
        m.weight.data.normal_(1.0,0.02)
        m.bias.data.fill_(0)
        
# this converts any pytorch tensor,
# an n-dimensional array, to a 
# variable and puts it on a gpu if
# a one is available
def to_variable(x):
    '''
    convert a tensor to a variable
    with gradient tracking
    '''
    if torch.cuda.is_available():
        x = x .cuda()
    return Variable(x)

# we're going normalize our images
# to make training the generator easier
# this de-normalizes the images coming out
# of the generator so they look intelligble
def denorm_monsters(x):
    renorm = (x*0.5)+0.5
    return renorm.clamp(0,1)

# this plots a bunch of pokemon
# at the end of each trainign round so
# we can get a sense for how our network
# is doing.
def plot_figure(fixed_noise):
    plt.figure()
    fixed_imgs = generator(fixed_noise)
    result = denorm_monsters(fixed_imgs.cpu().data)
    result = make_grid(result)
    result = transforms.Compose([transforms.ToPILImage()])(result)
    plt.imshow(result)
    plt.axis('off')
    plt.show()
    
# this plots a bunch of pokemon
# at the end of each trainign round so
# we can get a sense for how our network
# is doing.
def save_figure(fixed_noise, epoch):
    fixed_imgs = generator(fixed_noise)
    result = denorm_monsters(fixed_imgs.cpu().data)
    result = make_grid(result)
    save_image(result, os.path.join('/scratch', 'yns207', 'gif_component_%d.png' % epoch))

# %%
# create a generator and
# initialize its weights
generator = Generator()
generator = generator.apply(weights_init)

# create a discriminator and
# initialize its weights
discriminator = Discriminator()
discriminator = discriminator.apply(weights_init)

# create a loss object and optimizers
loss_func = nn.BCELoss()
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.99))
g_optimizer = optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.99))

# it a gpu is available, move all
# the models and the loss function
# to the gpu (more performant)
if torch.cuda.is_available():
    generator.cuda()
    discriminator.cuda()
    loss_func.cuda()

# %%
# create a fixed_noise variable so we can evaluate results
# consistently. if we don't do this we'll get different monsters
# everytime we re-run and it will be hard to eavluate our generator
fixed_noise = to_variable(torch.randn(batch_size, noise_dim, 1, 1))

# %%
# keep track of losses
# from the generator and
# discriminator
generator_losses = []
discriminator_losses = []

# for some number of rounds (epochs)
for epoch in range(n_epochs):
    # track losses for this epoch
    gen_loss_epoch = 0
    dis_loss_epoch_fake = 0
    dis_loss_epoch_real = 0
    batches_processed = 0
    # for every batch of images
    for i, image_batch in enumerate(monster_loader):
        # track the number of batches processed
        batches_processed += 1
        # get the batch size of the
        # current batch ()
        image_batch = image_batch[0]
        batch_size = image_batch.shape[0]
        
        # --- train discriminator ---
        # clear gradients
        discriminator.zero_grad()
        
        # train discriminator on real images
        real_images = to_variable(image_batch)
        real_outputs = discriminator(real_images)
        real_loss = loss_func(real_outputs, to_variable(torch.ones(real_outputs.data.shape))*label_smooth)
        real_loss.backward()
        dis_loss_epoch_real += torch.mean(real_loss.data)
        
        # train dsicriminator on generated images
        noise = to_variable(torch.randn(batch_size, noise_dim, 1, 1))
        fake_images = generator(noise)
        fake_outputs = discriminator(fake_images)
        fake_loss = loss_func(fake_outputs, to_variable(torch.zeros(fake_outputs.data.shape)))
        fake_loss.backward()
        dis_loss_epoch_fake += torch.mean(fake_loss.data)
        
        # update discriminator params
        d_optimizer.step()
        
        # --- train generator ---
        generator.zero_grad()
        
        # generate noise and feed it to the generator
        # to make an image
        noise = to_variable(torch.randn(batch_size, noise_dim, 1, 1))
        fake_images = generator(noise)
        dis_outputs = discriminator(fake_images)
        gen_loss = loss_func(dis_outputs, to_variable(torch.ones(dis_outputs.data.shape)))
        gen_loss.backward()
        gen_loss_epoch += torch.mean(gen_loss.data)
        
        # update generator params
        g_optimizer.step()
        
    discriminator_losses.append([dis_loss_epoch_real/batches_processed, dis_loss_epoch_fake/batches_processed])
    generator_losses.append(gen_loss_epoch/batches_processed)
        
    print('epoch {}'.format(epoch))
    print('generator loss: {:0.2f}, discriminator loss real: {:0.2f}, discriminator loss fake: {:0.2f}'.format(generator_losses[-1], discriminator_losses[-1][0], discriminator_losses[-1][1]))   
    
    plot_figure(fixed_noise)
    save_figure(fixed_noise, epoch)
    
    # save this epoch's model.
    torch.save(generator.state_dict(), os.path.join(pokemon_models, 'generator_dec317_ep_%d' % epoch))
    torch.save(discriminator.state_dict(), os.path.join(pokemon_models, 'discriminator_dec317_ep_%d' % epoch))
# Out:
# epoch 0
# generator loss: 5.38, discriminator loss real: 0.70, discriminator loss fake: 0.45
# epoch 1
# generator loss: 2.56, discriminator loss real: 0.64, discriminator loss fake: 0.35
# epoch 2
# generator loss: 2.63, discriminator loss real: 0.65, discriminator loss fake: 0.37
# epoch 3
# generator loss: 2.14, discriminator loss real: 0.70, discriminator loss fake: 0.42
# epoch 4
# generator loss: 2.18, discriminator loss real: 0.63, discriminator loss fake: 0.36
# epoch 5
# generator loss: 2.37, discriminator loss real: 0.63, discriminator loss fake: 0.34
# epoch 6
# generator loss: 2.84, discriminator loss real: 0.57, discriminator loss fake: 0.27
# epoch 7
# generator loss: 2.53, discriminator loss real: 0.59, discriminator loss fake: 0.30
# epoch 8
# generator loss: 2.58, discriminator loss real: 0.61, discriminator loss fake: 0.32
# epoch 9
# generator loss: 2.57, discriminator loss real: 0.59, discriminator loss fake: 0.30
# epoch 10
# generator loss: 2.56, discriminator loss real: 0.60, discriminator loss fake: 0.31
# epoch 11
# generator loss: 2.48, discriminator loss real: 0.60, discriminator loss fake: 0.30
# epoch 12
# generator loss: 2.62, discriminator loss real: 0.56, discriminator loss fake: 0.28
# epoch 13
# generator loss: 2.65, discriminator loss real: 0.57, discriminator loss fake: 0.28
# epoch 14
# generator loss: 2.77, discriminator loss real: 0.54, discriminator loss fake: 0.24
# epoch 15
# generator loss: 2.73, discriminator loss real: 0.57, discriminator loss fake: 0.27
# epoch 16
# generator loss: 2.74, discriminator loss real: 0.55, discriminator loss fake: 0.25
# epoch 17
# generator loss: 2.78, discriminator loss real: 0.54, discriminator loss fake: 0.25
# epoch 18
# generator loss: 2.80, discriminator loss real: 0.53, discriminator loss fake: 0.22
# epoch 19
# generator loss: 2.90, discriminator loss real: 0.54, discriminator loss fake: 0.23
# epoch 20
# generator loss: 2.91, discriminator loss real: 0.52, discriminator loss fake: 0.20
# epoch 21
# generator loss: 2.98, discriminator loss real: 0.51, discriminator loss fake: 0.20
# epoch 22
# generator loss: 3.04, discriminator loss real: 0.51, discriminator loss fake: 0.20
# epoch 23
# generator loss: 3.16, discriminator loss real: 0.50, discriminator loss fake: 0.19
# epoch 24
# generator loss: 3.34, discriminator loss real: 0.48, discriminator loss fake: 0.16
# epoch 25
# generator loss: 3.15, discriminator loss real: 0.50, discriminator loss fake: 0.18
# epoch 26
# generator loss: 3.31, discriminator loss real: 0.47, discriminator loss fake: 0.15
# epoch 27
# generator loss: 3.48, discriminator loss real: 0.48, discriminator loss fake: 0.15
# epoch 28
# generator loss: 3.50, discriminator loss real: 0.46, discriminator loss fake: 0.13
# epoch 29
# generator loss: 3.66, discriminator loss real: 0.46, discriminator loss fake: 0.12
# epoch 30
# generator loss: 3.62, discriminator loss real: 0.46, discriminator loss fake: 0.12
# epoch 31
# generator loss: 3.56, discriminator loss real: 0.46, discriminator loss fake: 0.13
# epoch 32
# generator loss: 3.62, discriminator loss real: 0.47, discriminator loss fake: 0.13
# epoch 33
# generator loss: 3.67, discriminator loss real: 0.44, discriminator loss fake: 0.10
# epoch 34
# generator loss: 3.75, discriminator loss real: 0.45, discriminator loss fake: 0.11
# epoch 35
# generator loss: 3.76, discriminator loss real: 0.45, discriminator loss fake: 0.11
# epoch 36
# generator loss: 3.77, discriminator loss real: 0.46, discriminator loss fake: 0.12
# epoch 37
# generator loss: 3.83, discriminator loss real: 0.43, discriminator loss fake: 0.08
# epoch 38
# generator loss: 3.86, discriminator loss real: 0.46, discriminator loss fake: 0.11
# epoch 39
# generator loss: 3.89, discriminator loss real: 0.43, discriminator loss fake: 0.09
# epoch 40
# generator loss: 3.91, discriminator loss real: 0.44, discriminator loss fake: 0.09
# epoch 41
# generator loss: 4.15, discriminator loss real: 0.42, discriminator loss fake: 0.08
# epoch 42
# generator loss: 4.13, discriminator loss real: 0.43, discriminator loss fake: 0.08
# epoch 43
# generator loss: 4.08, discriminator loss real: 0.43, discriminator loss fake: 0.09
# epoch 44
# generator loss: 4.11, discriminator loss real: 0.43, discriminator loss fake: 0.08
# epoch 45
# generator loss: 4.18, discriminator loss real: 0.43, discriminator loss fake: 0.07
# epoch 46
# generator loss: 4.21, discriminator loss real: 0.42, discriminator loss fake: 0.07
# epoch 47
# generator loss: 4.19, discriminator loss real: 0.44, discriminator loss fake: 0.08
# epoch 48
# generator loss: 4.18, discriminator loss real: 0.43, discriminator loss fake: 0.07
# epoch 49
# generator loss: 4.20, discriminator loss real: 0.41, discriminator loss fake: 0.06
# epoch 50
# generator loss: 4.09, discriminator loss real: 0.44, discriminator loss fake: 0.09
# epoch 51
# generator loss: 4.15, discriminator loss real: 0.41, discriminator loss fake: 0.06
# epoch 52
# generator loss: 4.37, discriminator loss real: 0.41, discriminator loss fake: 0.05
# epoch 53
# generator loss: 4.42, discriminator loss real: 0.42, discriminator loss fake: 0.05
# epoch 54
# generator loss: 4.29, discriminator loss real: 0.44, discriminator loss fake: 0.08
# epoch 55
# generator loss: 4.49, discriminator loss real: 0.40, discriminator loss fake: 0.04
# epoch 56
# generator loss: 4.47, discriminator loss real: 0.41, discriminator loss fake: 0.05
# epoch 57
# generator loss: 4.38, discriminator loss real: 0.41, discriminator loss fake: 0.05
# epoch 58
# generator loss: 4.50, discriminator loss real: 0.41, discriminator loss fake: 0.05
# epoch 59
# generator loss: 4.36, discriminator loss real: 0.41, discriminator loss fake: 0.05
# epoch 60
# generator loss: 4.53, discriminator loss real: 0.42, discriminator loss fake: 0.05
# epoch 61
# generator loss: 4.47, discriminator loss real: 0.40, discriminator loss fake: 0.04
# epoch 62
# generator loss: 4.57, discriminator loss real: 0.41, discriminator loss fake: 0.04
# epoch 63
# generator loss: 4.40, discriminator loss real: 0.41, discriminator loss fake: 0.05
# epoch 64
# generator loss: 4.68, discriminator loss real: 0.40, discriminator loss fake: 0.04
# epoch 65
# generator loss: 4.47, discriminator loss real: 0.41, discriminator loss fake: 0.04
# epoch 66
# generator loss: 4.51, discriminator loss real: 0.40, discriminator loss fake: 0.04
# epoch 67
# generator loss: 4.62, discriminator loss real: 0.40, discriminator loss fake: 0.04
# epoch 68
# generator loss: 4.49, discriminator loss real: 0.40, discriminator loss fake: 0.04
# epoch 69
# generator loss: 4.78, discriminator loss real: 0.39, discriminator loss fake: 0.03
# epoch 70
# generator loss: 4.58, discriminator loss real: 0.41, discriminator loss fake: 0.04
# epoch 71
# generator loss: 4.78, discriminator loss real: 0.39, discriminator loss fake: 0.03
# epoch 72
# generator loss: 4.75, discriminator loss real: 0.40, discriminator loss fake: 0.03
# epoch 73
# generator loss: 4.72, discriminator loss real: 0.41, discriminator loss fake: 0.04
# epoch 74
# generator loss: 4.64, discriminator loss real: 0.39, discriminator loss fake: 0.03
# epoch 75
# generator loss: 4.74, discriminator loss real: 0.39, discriminator loss fake: 0.03
# epoch 76
# generator loss: 4.83, discriminator loss real: 0.39, discriminator loss fake: 0.03
# epoch 77
# generator loss: 4.90, discriminator loss real: 0.38, discriminator loss fake: 0.03
# epoch 78
# generator loss: 4.72, discriminator loss real: 0.40, discriminator loss fake: 0.04
# epoch 79
# generator loss: 4.91, discriminator loss real: 0.38, discriminator loss fake: 0.03
# epoch 80
# generator loss: 4.84, discriminator loss real: 0.39, discriminator loss fake: 0.03
# epoch 81
# generator loss: 4.76, discriminator loss real: 0.39, discriminator loss fake: 0.03
# epoch 82
# generator loss: 4.85, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 83
# generator loss: 4.95, discriminator loss real: 0.38, discriminator loss fake: 0.03
# epoch 84
# generator loss: 4.86, discriminator loss real: 0.39, discriminator loss fake: 0.04
# epoch 85
# generator loss: 4.91, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 86
# generator loss: 4.79, discriminator loss real: 0.39, discriminator loss fake: 0.03
# epoch 87
# generator loss: 4.96, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 88
# generator loss: 4.92, discriminator loss real: 0.39, discriminator loss fake: 0.03
# epoch 89
# generator loss: 4.75, discriminator loss real: 0.39, discriminator loss fake: 0.03
# epoch 90
# generator loss: 4.94, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 91
# generator loss: 5.03, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 92
# generator loss: 4.89, discriminator loss real: 0.38, discriminator loss fake: 0.03
# epoch 93
# generator loss: 4.88, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 94
# generator loss: 4.92, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 95
# generator loss: 5.07, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 96
# generator loss: 5.15, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 97
# generator loss: 5.01, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 98
# generator loss: 5.00, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 99
# generator loss: 5.07, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 100
# generator loss: 5.07, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 101
# generator loss: 5.29, discriminator loss real: 0.37, discriminator loss fake: 0.01
# epoch 102
# generator loss: 5.11, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 103
# generator loss: 5.14, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 104
# generator loss: 5.18, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 105
# generator loss: 5.09, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 106
# generator loss: 5.08, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 107
# generator loss: 5.09, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 108
# generator loss: 5.08, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 109
# generator loss: 5.16, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 110
# generator loss: 5.15, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 111
# generator loss: 5.14, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 112
# generator loss: 5.16, discriminator loss real: 0.36, discriminator loss fake: 0.01
# epoch 113
# generator loss: 5.19, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 114
# generator loss: 5.25, discriminator loss real: 0.37, discriminator loss fake: 0.01
# epoch 115
# generator loss: 5.28, discriminator loss real: 0.37, discriminator loss fake: 0.02
# epoch 116
# generator loss: 5.21, discriminator loss real: 0.37, discriminator loss fake: 0.01
# epoch 117
# generator loss: 5.31, discriminator loss real: 0.37, discriminator loss fake: 0.01
# epoch 118
# generator loss: 5.27, discriminator loss real: 0.37, discriminator loss fake: 0.01
# epoch 119
# generator loss: 5.27, discriminator loss real: 0.38, discriminator loss fake: 0.02
# epoch 120
# generator loss: 5.13, discriminator loss real: 0.36, discriminator loss fake: 0.01
# epoch 121
# generator loss: 5.21, discriminator loss real: 0.37, discriminator loss fake: 0.01
# epoch 122
# generator loss: 5.30, discriminator loss real: 0.37, discriminator loss fake: 0.01
# epoch 123
# generator loss: 5.21, discriminator loss real: 0.37, discriminator loss fake: 0.01
# epoch 124
# generator loss: 5.28, discriminator loss real: 0.36, discriminator loss fake: 0.01

# %% [markdown]
# Let's just run the below two cells to repeatedly generate new monsters.

# %%
# create new noise to pass to the generator
noise = to_variable(torch.randn(batch_size, noise_dim, 1, 1))

# %%
# load the generator from epoch 90 of training
load_model = os.path.join(pokemon_models, 'generator_dec317_ep_%d' % 90)
generator_final = Generator()
generator_final.load_state_dict(torch.load(load_model))
generator_final.cuda()

# generate new monsters
imgs = generator_final(noise)
denormed_monsters = denorm_monsters(imgs.cpu().data)
grid = make_grid(denormed_monsters)
save_image(grid, os.path.join('/scratch', 'yns207', 'output_3.png'))
grid = transforms.Compose([transforms.ToPILImage()])(grid)

# plot those monsters
plt.figure(figsize=(20,15))
plt.imshow(grid)
plt.axis('off')
_ = plt.show()

# %%
# load the generator from epoch 90 of training
load_model = os.path.join(pokemon_models, 'generator_dec317_ep_%d' % 90)
generator_final = Generator()
generator_final.load_state_dict(torch.load(load_model))
generator_final.cuda()

imgs = generator_final(noise)
denormed_monster = denorm_monsters(imgs[30].cpu().data)
monster = np.transpose(denormed_monster.numpy(), (1,2,0))
monster = (monster*255).astype(np.uint8)
save_image(denormed_monster, os.path.join('/scratch', 'yns207', 'output_5.png'))
monster = transforms.Compose([transforms.ToTensor(), transforms.ToPILImage()])(monster)

plt.figure(figsize=(20,15))
plt.imshow(monster)
plt.axis('off')
_ = plt.show()
